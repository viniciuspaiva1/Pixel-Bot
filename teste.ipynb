# %%
import pyautogui
import pygetwindow as gw
import time
#x = pyautogui.locateAllOnScreen('sample/'+'galinheiro.png', confidence = conf)

# %%
x, y = pyautogui.locateCenterOnScreen('sample/'+'avatar.png', confidence= 0.5)
pyautogui.click(x,y)
a = 0
while a < 10:
    pyautogui.keyDown("right")
    time.sleep(1)
    a+=1
#pyautogui.keyUp("up")
# Out:
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     171         try:
# --> 172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyautogui\__init__.py in locateCenterOnScreen(*args, **kwargs)
#     203     def locateCenterOnScreen(*args, **kwargs):
# --> 204         return pyscreeze.locateCenterOnScreen(*args, **kwargs)
#     205
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in locateCenterOnScreen(image, **kwargs)
#     446     """
# --> 447     coords = locateOnScreen(image, **kwargs)
#     448     if coords is None:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     404             screenshotIm = screenshot(region=None)
# --> 405             retVal = locate(image, screenshotIm, **kwargs)
#     406             try:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in locate(needleImage, haystackImage, **kwargs)
#     382     kwargs['limit'] = 1
# --> 383     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384     if len(points) > 0:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256         if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257             raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258         else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.369)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18096/4003165337.py in <module>
# ----> 1 x, y = pyautogui.locateCenterOnScreen('sample/'+'avatar.png', confidence= 0.5)
#       2 pyautogui.click(x,y)
#       3 a = 0
#       4 while a < 10:
#       5     pyautogui.keyDown("right")
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
# --> 174             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#     175
#     176     return wrapper
#
# ImageNotFoundException:

# %%
time.sleep(2)

pyautogui.keyDown("right")
time.sleep(1)
pyautogui.keyUp("right")

pyautogui.keyDown("up")
time.sleep(1.2)
pyautogui.keyUp("up")

pyautogui.keyDown("up")
pyautogui.keyDown("left")
time.sleep(2)
pyautogui.keyUp("up")
pyautogui.keyUp("left")

x, y = pyautogui.locateCenterOnScreen('sample/'+'galinheiro.png', confidence= 0.5)
pyautogui.click(x,y)

# %%
time.sleep(3)
pyautogui.hotkey('z')
time.sleep(2)
x, y = pyautogui.locateCenterOnScreen('sample/'+'galinheiro_small.png', confidence= 0.5)
pyautogui.click(x,y)

# %%
windows = gw.getWindowsWithTitle('Pixels')
for window in windows:
    print(window.title)
# Out:
# ● teste.ipynb - Bot Pixels - Visual Studio Code
# Pixels: An Infinite World of Endless Adventure e mais 4 páginas - Pessoal — Microsoft​ Edge

# %%
import json
from pathlib import Path

json_file_path = Path('rotas_galinheiro.json')
json_data = []
if json_file_path.exists():
    with open(json_file_path, 'r') as existing_json_file:
        json_data = json.load(existing_json_file)

INITIAL_LAND_NUMBER = 1077
time.sleep(5)
for actual_land in range(INITIAL_LAND_NUMBER, INITIAL_LAND_NUMBER+100):
    print(f"Land Atual: {actual_land}")
    posicao = next((index for index, item in enumerate(json_data) if int(item["land_number"]) == actual_land), -1)
    if posicao != -1:
        print("\t Indo colher os ovos")
        completed_movement(json_data[posicao]['directions'])
    else:
        skip_land()

# %% [markdown]
# Ir ate o office
# Ir ate o tp
# inserir a land
# apertar enter
# iniciar rota

# %%
time.sleep(3)
pyautogui.write("1122")

# %%
def add_chickens(confidence = 0.6, num_chickens = 2):
    if pyautogui.locateCenterOnScreen('sample/'+f'galinheiro.png', confidence= 0.7):
        pyautogui.hotkey('6')
        for _ in range(0,num_chickens):
            x, y = pyautogui.locateCenterOnScreen('sample/'+f'galinheiro.png', confidence= 0.7)
            pyautogui.click(x,y)
            time.sleep(1)
        pyautogui.hotkey('6')

time.sleep(3)    
add_chickens()

# %%
import pyautogui
import time


def add_chickens(confidence = 0.5, num_chickens = 2):
    if pyautogui.locateCenterOnScreen('sample/'+f'galinheiro.png', confidence= 0.5):
        pyautogui.hotkey('6')
        x, y = pyautogui.locateCenterOnScreen('sample/'+f'galinheiro.png', confidence= 0.5)
        for _ in range(0,num_chickens):
            pyautogui.click(x,y)
            time.sleep(1.5)
        pyautogui.hotkey('6')


def collect_target(img):
    pyautogui.move(0,0, duration=0.5)
    x, y = pyautogui.locateCenterOnScreen('sample/'+f'{img}.png', confidence= 0.5)
    pyautogui.click(x,y)

def wait_loading_page(img, wait_time = 40):
    time_pass = 0
    while time_pass < wait_time:
        try:
            x, y = pyautogui.locateCenterOnScreen('sample/'+f'{img}.png', confidence= 0.6)
        except:
            time.sleep(1)
            pass
        else:
            time.sleep(1)
            return

def move(dir, length):
    pyautogui.keyDown(dir)
    time.sleep(length)
    pyautogui.keyUp(dir)

def foward_movement (directions):
    wait_loading_page("ancora")
    for dir in directions:
        move(dir['key_name'], dir['time_press'])

def skip_land(proportion = 1):
    '''
    The  proportion parameter its 1 for 100% time.
    
    The base time is 3 seconds
    '''
    SKIP_LAND_TIME_WALK = 3
    pyautogui.keyDown('right')
    time.sleep(SKIP_LAND_TIME_WALK*proportion)
    pyautogui.keyUp('right')

    wait_loading_page("ancora")

def completed_movement(directions, first_land = False, last_land = False): #The name should be changed for 'harvest'
    foward_movement(directions)
    
    time.sleep(0.1)
    add_chickens(num_chickens=1)
    collect_target("galinheiro")
    backward_movement(directions, first_land)

    time.sleep(0.1)
    if not last_land:
        skip_land(1)
    
    
def backward_movement(directions, first_land = False):
    aux = 1
    if first_land:
        aux = 0
    for dir in reversed(directions[aux:]): #Retirei o direction[1:]
        if dir['key_name'] == 'up':
            key_name = 'down'
        elif dir['key_name'] == 'down':
            key_name = 'up'
        elif dir['key_name'] == 'left':
            key_name = 'right'
        elif dir['key_name'] == 'right':
            key_name = 'left'
        move(key_name, dir['time_press'])
 

def walk_with_mouse(img, time_press, factor = 60):
    verify = False
    for _ in range(0, time_press):
        try:
            x, y = pyautogui.locateCenterOnScreen('sample/'+f'{img}.png', confidence= 0.6)
            pyautogui.mouseDown(x,y+factor)
            time.sleep(1)
            pyautogui.mouseUp()
        except:
            pass
        else:
            verify = True
    return verify

def go_through_door():
    for _ in range (0,3):
      try:
        x, y = pyautogui.locateCenterOnScreen('sample/'+f'office_door.png', confidence= 0.6)
        pyautogui.mouseDown(x,y)
        time.sleep(3)
        pyautogui.mouseUp()
      except:
          pass
      else:
          return True
      time.sleep(2)
    
def go_to_land_office():
    
    with open("basics_movements.json", 'r') as existing_json_file:
        BASIC_MOVEMENTS = json.load(existing_json_file)

    if walk_with_mouse('statue_1', 4):
        foward_movement(BASIC_MOVEMENTS['statue_up'])
        go_through_door()

    elif walk_with_mouse('statue_2', 4):
        foward_movement(BASIC_MOVEMENTS['statue_down'])
        go_through_door()

def set_land_number_infiniportal(land_number):
    x, y = pyautogui.locateCenterOnScreen('sample/'+f'infiniportal.png', confidence= 0.6)
    pyautogui.click(x,y)
    time.sleep(0.5)
    pyautogui.write(str(land_number))


def go_to_terravilla():
    x, y = pyautogui.locateCenterOnScreen('sample/'+'terravilla_icon.png', confidence= 0.6)
    pyautogui.click(x,y)
    time.sleep(0.5)
    x, y = pyautogui.locateCenterOnScreen('sample/'+'go_to_terravilla.png', confidence= 0.8)
    pyautogui.click(x,y)

def travel_to_specific_land(land_number):
    with open("basics_movements.json", 'r') as existing_json_file:
        BASIC_MOVEMENTS = json.load(existing_json_file)
    go_to_terravilla()
    wait_loading_page('ancora')
    go_to_land_office()
    foward_movement(BASIC_MOVEMENTS['go_infiniportal'])
    set_land_number_infiniportal(land_number)
    time.sleep(0.5)
    pyautogui.hotkey('enter')

# %%
import json

with open("rotas_galinheiro.json", 'r') as existing_json_file:
    LAND_MOVEMENTS = json.load(existing_json_file)

with open("rotations.json", 'r') as existing_json_file:
    ROTATIONS = json.load(existing_json_file)

vector_rotations = list(ROTATIONS.values())
time.sleep(4)
for rotation in vector_rotations[7:]:
    travel_to_specific_land(rotation['initial_land'])
    time.sleep(1)
    for actual_land in range(rotation['initial_land'], rotation['final_land']+1):
        print(f"Land Atual: {actual_land}")
        posicao = next((index for index, item in enumerate(LAND_MOVEMENTS) if int(item["land_number"]) == actual_land), -1)

        if posicao != -1 and actual_land != rotation['final_land']:
            print("\t Indo colher os ovos")
            if actual_land == rotation['initial_land']:
                completed_movement(LAND_MOVEMENTS[posicao]['directions'], True)
            else:
                completed_movement(LAND_MOVEMENTS[posicao]['directions'])
        elif posicao != -1 and actual_land == rotation['final_land']:
            print("\t Indo colher os ovos")
            completed_movement(LAND_MOVEMENTS[posicao]['directions'], last_land= True)
        else:
            skip_land()
# Out:
# Land Atual: 922
# 	 Indo colher os ovos
# Land Atual: 923
# 	 Indo colher os ovos
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     171         try:
# --> 172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyautogui\__init__.py in locateCenterOnScreen(*args, **kwargs)
#     203     def locateCenterOnScreen(*args, **kwargs):
# --> 204         return pyscreeze.locateCenterOnScreen(*args, **kwargs)
#     205
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in locateCenterOnScreen(image, **kwargs)
#     446     """
# --> 447     coords = locateOnScreen(image, **kwargs)
#     448     if coords is None:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     404             screenshotIm = screenshot(region=None)
# --> 405             retVal = locate(image, screenshotIm, **kwargs)
#     406             try:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in locate(needleImage, haystackImage, **kwargs)
#     382     kwargs['limit'] = 1
# --> 383     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384     if len(points) > 0:
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyscreeze\__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256         if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257             raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258         else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.149)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13304/1643236814.py in <module>
#      21                 completed_movement(LAND_MOVEMENTS[posicao]['directions'], True)
#      22             else:
# ---> 23                 completed_movement(LAND_MOVEMENTS[posicao]['directions'])
#      24         elif posicao != -1 and actual_land == rotation['final_land']:
#      25             print("\t Indo colher os ovos")
#
# ~\AppData\Local\Temp/ipykernel_13304/1965448819.py in completed_movement(directions, first_land, last_land)
#      57
#      58     time.sleep(0.1)
# ---> 59     add_chickens(num_chickens=1)
#      60     collect_target("galinheiro")
#      61     backward_movement(directions, first_land)
#
# ~\AppData\Local\Temp/ipykernel_13304/1965448819.py in add_chickens(confidence, num_chickens)
#       4
#       5 def add_chickens(confidence = 0.5, num_chickens = 2):
# ----> 6     if pyautogui.locateCenterOnScreen('sample/'+f'galinheiro.png', confidence= 0.5):
#       7         pyautogui.hotkey('6')
#       8         x, y = pyautogui.locateCenterOnScreen('sample/'+f'galinheiro.png', confidence= 0.5)
#
# c:\Users\vinic\AppData\Local\Programs\Python\Python39\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
# --> 174             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#     175
#     176     return wrapper
#
# ImageNotFoundException:

# %%
with open("rotations.json", 'r') as existing_json_file:
    ROTATIONS = json.load(existing_json_file)

ve = list(ROTATIONS.values())
print(ve)
# Out:
# [{'initial_land': 46, 'final_land': 51}, {'initial_land': 189, 'final_land': 194}, {'initial_land': 249, 'final_land': 253}, {'initial_land': 500, 'final_land': 504}, {'initial_land': 578, 'final_land': 582}, {'initial_land': 805, 'final_land': 809}, {'initial_land': 816, 'final_land': 820}, {'initial_land': 922, 'final_land': 926}, {'initial_land': 2078, 'final_land': 2087}, {'initial_land': 2123, 'final_land': 2128}, {'initial_land': 2227, 'final_land': 2231}, {'initial_land': 2362, 'final_land': 2367}, {'initial_land': 2418, 'final_land': 2421}, {'initial_land': 1101, 'final_land': 1105}, {'initial_land': 1175, 'final_land': 1179}, {'initial_land': 1222, 'final_land': 1227}, {'initial_land': 1296, 'final_land': 1300}, {'initial_land': 1338, 'final_land': 1342}, {'initial_land': 1385, 'final_land': 1389}, {'initial_land': 1395, 'final_land': 1412}, {'initial_land': 1439, 'final_land': 1445}, {'initial_land': 1454, 'final_land': 1458}, {'initial_land': 1643, 'final_land': 1648}, {'initial_land': 1672, 'final_land': 1676}, {'initial_land': 1701, 'final_land': 1707}, {'initial_land': 1766, 'final_land': 1770}, {'initial_land': 1775, 'final_land': 1781}, {'initial_land': 1873, 'final_land': 1877}, {'initial_land': 1964, 'final_land': 1969}]

# %%
time.sleep(2)

pyautogui.keyDown("right")
time.sleep(1.1)
pyautogui.keyUp("right")

pyautogui.keyDown("up")
time.sleep(3.2)
pyautogui.keyUp("up")

pyautogui.keyDown("left")
time.sleep(1.6)
pyautogui.keyUp("left")

pyautogui.keyDown("up")
time.sleep(0.34)
pyautogui.keyUp("up")

x, y = pyautogui.locateCenterOnScreen('sample/'+'galinheiro.png', confidence= 0.5)
pyautogui.click(x,y)

# %%
x, y = pyautogui.locateCenterOnScreen('sample/'+'galinheiro.png', confidence= 0.5)
pyautogui.click(x,y)
